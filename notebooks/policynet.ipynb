# %%
import sys
sys.path.append("../")

# %%
import alphatsp
import alphatsp.tsp
import alphatsp.util
import alphatsp.solvers.exact
import alphatsp.solvers.gurobi
import alphatsp.solvers.heuristics
import alphatsp.solvers.mcts

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch.distributions.categorical import Categorical

# %%
import torch_geometric
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.data import Data, DataLoader

# %%
import tqdm

# %%
import numpy as np
import random
import copy
import math
import queue

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, d=2):
        super(PolicyNetwork, self).__init__()
        self.conv1 = GCNConv(d,  16)
        self.conv2 = GCNConv(16, 16)
        self.conv3 = GCNConv(16, 1)
        self.fc    = nn.Linear(16, 1)
    
    def forward(self, graph):
        x, edges, choices = graph.pos, graph.edge_index, graph.y
        
        x = self.conv1(x, edges)
        x = F.relu(x)
        x = self.conv2(x, edges)
        x = F.relu(x)
        
        c = self.conv3(x, edges)
        choice = torch.masked_select(c.squeeze(), choices)
        choice = F.softmax(choice, dim=0)
        
        v = global_mean_pool(x, torch.zeros(graph.num_nodes, dtype=torch.long))
        value = self.fc(v)

        return choice, value
    
policy_network = PolicyNetwork()
optimizer = torch.optim.Adam(params=policy_network.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

# %%
class MCTSNode:

    def __init__(self, p=None, t=[0], r=None, tsp=None):
        self.parent = p
        self.tsp = tsp
        self.tour = t
        self.remaining = r if r is not None else list(range(1, tsp.n))
        self.visits = 0
        self.total_score = 0
        self.avg_score = 1 / (len(self.remaining)+1)
        self.c = 0.7
        self.n = tsp.n
        self.children = []
        self.graph = None
        self.action = self.tour[-1]

    def expand(self):
        k = random.choice(self.remaining)
        t = copy.copy(self.tour)
        r = copy.copy(self.remaining)
        t.append(k)
        r.remove(k)
        child = MCTSNode(self, t, r, self.tsp)
        self.children.append(child)
        return child
    
    def add_child(self, k):
        for child in self.children:
            if child.action == k:
                return child
        t = copy.copy(self.tour)
        r = copy.copy(self.remaining)
        t.append(k)
        r.remove(k)
        child = MCTSNode(self, t, r, self.tsp)
        self.children.append(child)
        return child

    def backprop(self, reward):
        self.visits += 1
        self.total_score += reward
        self.avg_score = self.total_score / self.visits
        if self.parent is not None:
            self.parent.backprop(reward)

    def simulate(self):
        random.shuffle(self.remaining)
        t = self.tour + self.remaining + [0]
        return self.tsp.payoff(t)

    def has_children(self):
        return len(self.children) != 0

    def is_leaf(self):
        return len(self.tour) == self.n
    
    def is_fully_expanded(self):
        return len(self.remaining) == len(self.children)

    def get_tour(self):
        return self.tour + [self.tour[0]]

    def best_child_score(self):
        return max(self.children, key = lambda child: child.avg_score)

    def best_child_uct(self):
        k = math.log(self.visits)
        return max(self.children, key = lambda child: child.avg_score + self.c * math.sqrt(2 * k / child.visits))

    def best_child_visits(self):
        return max(self.children, key = lambda child: child.visits)
    
    def best_child_policy(self, model):
        if len(self.children) == 0: raise Exception("No children to select from.")
        if len(self.children) == 1: return self.children[0]
        
        actions = [child.action for child in self.children]
        r = list(set.intersection(set(actions), set(self.remaining)))
        z = np.zeros(self.n, dtype=np.int)
        z[r] = 1
        z = z[self.remaining]
        
        graph = self.construct_graph()
        pred, value = model(graph)
         
        pred = pred.squeeze()[z]
        selection = torch.argmax(pred)
        
        return self.children[selection]
    
    def select_child_policy(self, model):
        if len(self.children) == 0: raise Exception("No children to select from.")
        if len(self.children) == 1: return self.children[0]
        graph = self.construct_graph()
        pred, value = model(graph)
        selection = torch.multinomial(pred.squeeze(), 1)
        return self.children[selection]
    
    def best_remaining_policy(self, model):
        if len(self.remaining) == 0: raise Exception("No remaining to select from.")
        if len(self.remaining) == 1: return self.add_child(self.remaining[0])
        
        graph = self.construct_graph()
        pred, value = model(graph)
        
        selection = torch.argmax(pred.squeeze()).item()
        selection = self.remaining[selection]
        
        return self.add_child(selection)
    
    def select_remaining_policy(self, model):
        if len(self.remaining) == 0: raise Exception("No remaining to select from.")
        if len(self.remaining) == 1: return self.add_child(self.remaining[0])
        
        graph = self.construct_graph()
        pred, value = model(graph)
        
        selection = torch.argmax(pred.squeeze()).item()
        selection = self.remaining[selection]
        
        selection = torch.multinomial(pred.squeeze(), 1)
        return self.add_child(selection)
    
    def construct_graph(self):
        if self.graph is not None:
            return self.graph

        points = torch.tensor(self.tsp.points).to(dtype=torch.float)

        edges = torch.zeros((2, len(self.tour)-1), dtype=torch.long)
        for i in range(len(self.tour)-1):
            edges[0, i] = self.tour[i]
            edges[1, i] = self.tour[i+1]

        choices = torch.zeros(self.n, dtype=torch.uint8)
        choices[self.remaining] = 1
        
        x = torch.cat([points, choices.unsqueeze(-1).to(dtype=torch.float)], dim=-1)

        self.graph = Data(x=x, pos=points, edge_index=edges, y=choices)
        
        return self.graph

# %%
class MCTSSolver:
    
    def __init__(self, tsp, iterations=1000):
        self.tsp = tsp
        self.root_node = MCTSNode(tsp=self.tsp)
        self.iterations = iterations
    
    def solve(self):
        node = self.root_node
        while not node.is_leaf():
            node = self.mcts_search(node)
        mcts_tour = node.get_tour()
        mcts_payoff = self.tsp.tour_length(mcts_tour)
        return mcts_tour, mcts_payoff

    def mcts_search(self, start_node):
        for _ in range(self.iterations):
            node = self.tree_policy(start_node)
            pay = node.simulate()
            node.backprop(pay)
        return start_node.best_child_score()

    def tree_policy(self, start_node):
        node = start_node
        while not node.is_leaf():
            if not node.is_fully_expanded():
                return node.expand()
            else:
                node = node.best_child_uct()
        return node

# %%
class PolicySolver:
    
    def __init__(self, tsp, model):
        self.tsp = tsp
        self.root_node = MCTSNode(tsp=self.tsp)
        self.model = model
    
    def solve(self):
        node = self.root_node
        while not node.is_leaf():
            node = node.best_remaining_policy(model=self.model)
        mcts_tour = node.get_tour()
        mcts_payoff = self.tsp.tour_length(mcts_tour)
        return mcts_tour, mcts_payoff

# %%
class PolicyMCTSSolver:
    
    def __init__(self, tsp, model, iterations=50):
        self.tsp = tsp
        self.root_node = MCTSNode(tsp=self.tsp)
        self.iterations = iterations
        self.model = model
    
    def solve(self):
        node = self.root_node
        while not node.is_leaf():
            node = self.mcts_search(node)
        mcts_tour = node.get_tour()
        mcts_payoff = self.tsp.tour_length(mcts_tour)
        return mcts_tour, mcts_payoff

    def mcts_search(self, start_node):
        for _ in range(self.iterations):
            node = self.tree_policy(start_node)
            pay = node.simulate()
            node.backprop(pay)
        return start_node.best_child_score()

    def tree_policy(self, start_node):
        node = start_node
        while not node.is_leaf():
            if not node.is_fully_expanded():
                return node.expand()
            else:
                node = node.select_child_policy(self.model)
        return node

# %%
class MCTSTrainer:
    
    def __init__(self, tsp, model, example_queue, iterations=1000):
        self.tsp = tsp
        self.root_node = MCTSNode(tsp=self.tsp)
        self.iterations = iterations
        self.example_queue = example_queue
        self.model = model
        self.losses = []
    
    def solve(self):
        node = self.root_node
        while not node.is_leaf():
            node = self.mcts_search(node)
            self.generate_example(node.parent)
        mcts_tour = node.get_tour()
        mcts_payoff = self.tsp.tour_length(mcts_tour)
        return mcts_tour, mcts_payoff

    def mcts_search(self, start_node):
        for _ in range(self.iterations):
            node = self.tree_policy(start_node)
            pay = node.simulate()
            node.backprop(pay)
        return start_node.best_child_score()

    def tree_policy(self, start_node):
        node = start_node
        while not node.is_leaf():
            if not node.is_fully_expanded():
                return node.expand()
            else:
                node = node.best_child_uct()
        return node
    
    def generate_example(self, node):
        
        # construct graph
        graph = node.construct_graph()
        
        # construct labels
        
        choice_probs = [(child.tour[-1], child.visits) for child in node.children]
        choice_probs = sorted(choice_probs, key = lambda c: c[1])
        choice_probs = [c[0] for c in choice_probs]
        choice_probs = torch.tensor(choice_probs).to(dtype=torch.float)
        choice_probs = choice_probs / choice_probs.sum()
        
        choice = torch.argmax(choice_probs)
        
        pred_value = torch.tensor(node.avg_score)
        
        # add to queue
        example = {
            "graph": graph,
            "choice_probs": choice_probs,
            "choice": choice,
            "pred_value": pred_value,
        }
        self.example_queue.put(example)
        
    def train_example(self):
        self.model.train()
        
        example = self.example_queue.get()
        graph, choice_probs, value = example["graph"], example["choice_probs"], example["pred_value"]
        
        pred_choices, pred_value = self.model(graph)
        loss = loss_fn(pred_choices, choice_probs) + (0.2 * loss_fn(pred_value, value))
        
        self.losses.append(loss.item())
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    def train(self):
        model.train()
        while not self.example_queue.empty():

            example = self.example_queue.get()
            graph, choice_probs, value = example["graph"], example["choice_probs"], example["pred_value"]
            
            pred_choices, pred_value = self.model(graph)
            loss = loss_fn(pred_choices, choice_probs) + (0.2 * loss_fn(pred_value, value))
            
            self.losses.append(loss.item())
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

# %%
train_queue = queue.Queue()

# %%
tsp = alphatsp.tsp.TSP(10, 2)
solver = MCTSSolver(tsp)
node = solver.solve()

# %%
for _ in range(5):
    tsp = alphatsp.tsp.TSP(10, 2)
    solver = MCTSTrainer(tsp, train_queue)
    solver.solve()
while not train_queue.empty():
    print(train_queue.get())
# Out:
# {'graph': Data(edge_index=[2, 0], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1389, 0.1944, 0.0278, 0.0833, 0.0833, 0.2222, 0.0278, 0.1667, 0.0556]), 'choice': tensor(5), 'pred_value': tensor(0.8006)}
# {'graph': Data(edge_index=[2, 1], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.0811, 0.1081, 0.0270, 0.0270, 0.1892, 0.2432, 0.1622, 0.1622]), 'choice': tensor(5), 'pred_value': tensor(0.8151)}
# {'graph': Data(edge_index=[2, 2], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.0263, 0.0789, 0.0789, 0.2368, 0.1053, 0.2368, 0.2368]), 'choice': tensor(6), 'pred_value': tensor(0.8225)}
# {'graph': Data(edge_index=[2, 3], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.0476, 0.3333, 0.0476, 0.1905, 0.1905, 0.1905]), 'choice': tensor(1), 'pred_value': tensor(0.8305)}
# {'graph': Data(edge_index=[2, 4], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.0500, 0.4000, 0.2500, 0.1500, 0.1500]), 'choice': tensor(1), 'pred_value': tensor(0.8431)}
# {'graph': Data(edge_index=[2, 5], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.4444, 0.0556, 0.4444, 0.0556]), 'choice': tensor(2), 'pred_value': tensor(0.8555)}
# {'graph': Data(edge_index=[2, 6], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.4444, 0.2778, 0.2778]), 'choice': tensor(0), 'pred_value': tensor(0.8566)}
# {'graph': Data(edge_index=[2, 7], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.5000, 0.5000]), 'choice': tensor(1), 'pred_value': tensor(0.8603)}
# {'graph': Data(edge_index=[2, 8], pos=[10, 2], y=[10]), 'choice_probs': tensor([1.]), 'choice': tensor(0), 'pred_value': tensor(0.8603)}
# {'graph': Data(edge_index=[2, 0], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1064, 0.0851, 0.1915, 0.0426, 0.1277, 0.1064, 0.0851, 0.1915, 0.0638]), 'choice': tensor(7), 'pred_value': tensor(0.7706)}
# {'graph': Data(edge_index=[2, 1], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1429, 0.1714, 0.1714, 0.0286, 0.0286, 0.1429, 0.1143, 0.2000]), 'choice': tensor(7), 'pred_value': tensor(0.7780)}
# {'graph': Data(edge_index=[2, 2], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2500, 0.1875, 0.1875, 0.0312, 0.0312, 0.1562, 0.1562]), 'choice': tensor(0), 'pred_value': tensor(0.7867)}
# {'graph': Data(edge_index=[2, 3], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2609, 0.3913, 0.1739, 0.0870, 0.0435, 0.0435]), 'choice': tensor(1), 'pred_value': tensor(0.8205)}
# {'graph': Data(edge_index=[2, 4], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2667, 0.2000, 0.1333, 0.2000, 0.2000]), 'choice': tensor(0), 'pred_value': tensor(0.8383)}
# {'graph': Data(edge_index=[2, 5], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2500, 0.2500, 0.2500, 0.2500]), 'choice': tensor(3), 'pred_value': tensor(0.8493)}
# {'graph': Data(edge_index=[2, 6], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.3333, 0.3333, 0.3333]), 'choice': tensor(2), 'pred_value': tensor(0.8576)}
# {'graph': Data(edge_index=[2, 7], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.5000, 0.5000]), 'choice': tensor(1), 'pred_value': tensor(0.8601)}
# {'graph': Data(edge_index=[2, 8], pos=[10, 2], y=[10]), 'choice_probs': tensor([1.]), 'choice': tensor(0), 'pred_value': tensor(0.8601)}
# {'graph': Data(edge_index=[2, 0], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.0816, 0.1837, 0.0204, 0.0408, 0.1633, 0.1633, 0.1020, 0.1224, 0.1224]), 'choice': tensor(1), 'pred_value': tensor(0.7224)}
# {'graph': Data(edge_index=[2, 1], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1143, 0.1143, 0.0571, 0.0286, 0.2286, 0.2286, 0.0857, 0.1429]), 'choice': tensor(5), 'pred_value': tensor(0.7432)}
# {'graph': Data(edge_index=[2, 2], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2258, 0.1290, 0.0323, 0.2258, 0.0323, 0.2581, 0.0968]), 'choice': tensor(5), 'pred_value': tensor(0.7647)}
# {'graph': Data(edge_index=[2, 3], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2000, 0.2571, 0.2571, 0.2286, 0.0286, 0.0286]), 'choice': tensor(2), 'pred_value': tensor(0.7732)}
# {'graph': Data(edge_index=[2, 4], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1892, 0.2432, 0.2432, 0.2162, 0.1081]), 'choice': tensor(2), 'pred_value': tensor(0.7914)}
# {'graph': Data(edge_index=[2, 5], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.4500, 0.1000, 0.1000, 0.3500]), 'choice': tensor(0), 'pred_value': tensor(0.8008)}
# {'graph': Data(edge_index=[2, 6], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.6667, 0.1667, 0.1667]), 'choice': tensor(0), 'pred_value': tensor(0.8176)}
# {'graph': Data(edge_index=[2, 7], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.5000, 0.5000]), 'choice': tensor(1), 'pred_value': tensor(0.8209)}
# {'graph': Data(edge_index=[2, 8], pos=[10, 2], y=[10]), 'choice_probs': tensor([1.]), 'choice': tensor(0), 'pred_value': tensor(0.8209)}
# {'graph': Data(edge_index=[2, 0], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.0408, 0.1429, 0.1429, 0.0816, 0.0816, 0.0204, 0.1633, 0.1633, 0.1633]), 'choice': tensor(8), 'pred_value': tensor(0.7868)}
# {'graph': Data(edge_index=[2, 1], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1163, 0.1395, 0.1163, 0.1628, 0.0233, 0.1395, 0.1395, 0.1628]), 'choice': tensor(7), 'pred_value': tensor(0.7923)}
# {'graph': Data(edge_index=[2, 2], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1538, 0.2308, 0.1154, 0.0385, 0.0385, 0.0769, 0.3462]), 'choice': tensor(6), 'pred_value': tensor(0.8014)}
# {'graph': Data(edge_index=[2, 3], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2222, 0.1667, 0.3333, 0.0556, 0.1111, 0.1111]), 'choice': tensor(2), 'pred_value': tensor(0.8383)}
# {'graph': Data(edge_index=[2, 4], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2105, 0.2105, 0.2632, 0.2632, 0.0526]), 'choice': tensor(3), 'pred_value': tensor(0.8470)}
# {'graph': Data(edge_index=[2, 5], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2381, 0.1905, 0.2857, 0.2857]), 'choice': tensor(3), 'pred_value': tensor(0.8506)}
# {'graph': Data(edge_index=[2, 6], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2500, 0.3333, 0.4167]), 'choice': tensor(2), 'pred_value': tensor(0.8533)}
# {'graph': Data(edge_index=[2, 7], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.5000, 0.5000]), 'choice': tensor(1), 'pred_value': tensor(0.8563)}
# {'graph': Data(edge_index=[2, 8], pos=[10, 2], y=[10]), 'choice_probs': tensor([1.]), 'choice': tensor(0), 'pred_value': tensor(0.8563)}
# {'graph': Data(edge_index=[2, 0], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1400, 0.1400, 0.1600, 0.0600, 0.1600, 0.1200, 0.0600, 0.0600, 0.1000]), 'choice': tensor(4), 'pred_value': tensor(0.7474)}
# {'graph': Data(edge_index=[2, 1], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1628, 0.2093, 0.0930, 0.1395, 0.2093, 0.0930, 0.0698, 0.0233]), 'choice': tensor(4), 'pred_value': tensor(0.7612)}
# {'graph': Data(edge_index=[2, 2], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1569, 0.1373, 0.1176, 0.1765, 0.1765, 0.0588, 0.1765]), 'choice': tensor(6), 'pred_value': tensor(0.7728)}
# {'graph': Data(edge_index=[2, 3], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1154, 0.2308, 0.2308, 0.1154, 0.1538, 0.1538]), 'choice': tensor(2), 'pred_value': tensor(0.7844)}
# {'graph': Data(edge_index=[2, 4], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.1071, 0.2857, 0.2857, 0.0714, 0.2500]), 'choice': tensor(2), 'pred_value': tensor(0.8042)}
# {'graph': Data(edge_index=[2, 5], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2308, 0.4615, 0.1538, 0.1538]), 'choice': tensor(1), 'pred_value': tensor(0.8144)}
# {'graph': Data(edge_index=[2, 6], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.2727, 0.3636, 0.3636]), 'choice': tensor(2), 'pred_value': tensor(0.8332)}
# {'graph': Data(edge_index=[2, 7], pos=[10, 2], y=[10]), 'choice_probs': tensor([0.5000, 0.5000]), 'choice': tensor(1), 'pred_value': tensor(0.8437)}
# {'graph': Data(edge_index=[2, 8], pos=[10, 2], y=[10]), 'choice_probs': tensor([1.]), 'choice': tensor(0), 'pred_value': tensor(0.8437)}

# %%
for _ in range(700):
    tsp = alphatsp.tsp.TSP(20, 2)
    solver = MCTSTrainer(tsp, train_queue)
    solver.solve()

# %%
def train(model):
    losses = []
    model.train()
    while not train_queue.empty():
        example = train_queue.get()
        graph, choice_probs, value = example["graph"], example["choice_probs"], example["pred_value"]
        pred_choices, pred_value = model(graph)
        loss = loss_fn(pred_choices, choice_probs) + (0.2 * loss_fn(pred_value, value))
        losses.append(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    return model, losses

# %%
policy_network, losses = train(policy_network)

# %%
plt.scatter(x=np.arange(len(losses)), y=losses, marker='.')
plt.show()

# %%
for _ in range(5):
    tsp = alphatsp.tsp.TSP(20, 2)
    solver = PolicySolver(tsp, policy_network)
    print(solver.solve())
# Out:
# ([0, 8, 9, 1, 19, 15, 3, 14, 18, 13, 10, 2, 16, 12, 17, 7, 5, 4, 11, 6, 0], 11.90254787457621)
# ([0, 1, 14, 3, 9, 12, 5, 10, 7, 8, 6, 4, 2, 16, 17, 18, 15, 13, 19, 11, 0], 10.1130635197178)
# ([0, 5, 17, 6, 8, 19, 1, 12, 16, 13, 3, 9, 4, 15, 2, 10, 11, 18, 14, 7, 0], 7.706859995211765)
# ([0, 18, 4, 9, 16, 2, 10, 11, 1, 7, 8, 13, 12, 3, 14, 15, 17, 19, 5, 6, 0], 5.61296216397995)
# ([0, 15, 13, 8, 9, 5, 16, 18, 10, 19, 17, 11, 12, 7, 1, 4, 3, 6, 14, 2, 0], 7.370909506623001)

# %%
# torch.save(policy_network.state_dict(), "policy_network_01.pth")
